# %%
from transformers import AutoTokenizer, AutoModel

# %%
# !hf download zai-org/chatglm3-6b --local-dir ./pretrained_models/zai-org/chatglm3-6b

# %%
tokenizer = AutoTokenizer.from_pretrained(
    "./pretrained_models/zai-org/chatglm3-6b", trust_remote_code=True
)
tokenizer

# %%
model = AutoModel.from_pretrained(
    "./pretrained_models/zai-org/chatglm3-6b", trust_remote_code=True
)
model
